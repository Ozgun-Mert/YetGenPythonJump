# %% [markdown]
# # Problem 1 Aradaki Tam Sayılar
#
# Kullanıcıdan iki adet sayı alınız, bu sayılar arasındaki tam sayıları ekrana yazdıran bir program yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
a = int(input("Bir sayı giriniz."))
b = int(input("Bir sayı giriniz."))
for i in range(a, b+1):
    print(i)
# Out:
# 5
# 6
# 7

# %% [markdown]
# # Problem 2 Faktöriyel
#
# Kullanıcıdan bir sayı alınız ve alınan sayının faktöriyelini hesaplayan bir program yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
faktoriyel = 1
sayi = int(input("Bir sayı giriniz."))
if (sayi == 0 or sayi == 1):
        print(1)
else:
    while sayi >=1:
        faktoriyel *= sayi
        sayi -=1
    print(faktoriyel)
# Out:
# 120

# %% [markdown]
# # Problem 3 Virgül ile Ayırma
#
# Kullanıcıdan bir metin halinde virgül ile ayrılmış sayılar alınız ve aldığınız her bir sayıyı listeye atayınız, daha sonra listedeki her elemanı toplayıp ekrana bastıran bir program yazınız.
#
# <h4>Sample Input</h4>
# <p>
# Lutfen sayilari virgul ile ayrirarak giriniz: 5,14,7,2,1
# </p>
# <h4>Output</h4>
#
# Toplam: 29

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sayilar = input("Sayıları arasında virgül olacak şekilde giriniz.")
sayilar = sayilar.split(",")
toplam = 0
for sayi in sayilar:
    sayi = int(sayi)
    toplam+=sayi

print(toplam)
# Out:
# 155

# %% [markdown]
# # Problem 4 Büyük Sayı
#
# Kullanıcıdan alınan iki sayıdan büyük olanı bulup, ekrana yazdıran bir fonksiyon yazınız.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
a = int(input("Bir sayı giriniz."))
b = int(input("Bir sayı giriniz."))

if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print(f"{a} sayısı {b} sayısına eşittir.")
# Out:
# 10 sayısı 10 sayısına eşittir.

# %% [markdown]
# # Problem 5 Ürün Kayıt Uygulaması
# Programımız ilk olarak kullanıcıdan, kaydı yapılacak ürünlerin sayısını isteyecek. Ardından yazılmış olan ürün sayısı kadar ürün ismi ve ürün fiyatı bilgisini kullanıcıdan alacak. Son olarak ise ürünleri ekrana yazdıracağız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen kac adet urun gireceginizi yaziniz: 3
# <br/>
# 1. Urununuzun ismini giriniz: Mentos
# <br/>
# 1. Urununuzun fiyatini giriniz: 1
# <br/>
# 2. Urununuzun ismini giriniz: Meybuz
# <br/>
# 2. Urununuzun fiyatini giriniz: 0.25
# <br/>
# 3. Urununuzun ismini giriniz: Uzun Şeker
# <br/>
# 3. Urununuzun fiyatini giriniz: 0.75
# <br/>
# <h4>Output:</h4>
# 1. Urun: Mentos - 1 TL
# <br/>
# 2. Urun: Meybuz - 0.25 TL
# <br/>
# 3. Urun: Uzun Şeker - 0.75 TL
# </p>

# %%
# 5.Problemin Çözümünü Buraya Yazınız
sayi = int(input("Kaç tane ürün girceğinizi giriniz."))
for i in range(sayi):
    urunIsim = input(f"{i+1}. ürününüzün ismini giriniz.")
    urunFiyat = float(input(f"{i+1}. ürününüzün fiyatını giriniz."))
    print(f"{i+1}. Ürün: {urunIsim} - {urunFiyat} TL")
# Out:
# 1. Ürün: Mentos - 1.0 TL
# 2. Ürün: Meybuz - 0.25 TL
# 3. Ürün: Uzun Şeker - 0.75 TL

# %% [markdown]
# # Problem 6 Türkçe Karakter Çevirici
# Programa girilen dosya ismindeki Türkçe karakterleri, İngilizce'ye çeviren programı yazınız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen dosya ismi giriniz: fotoğraf.jpeg
# <br>
# Dosya ismi: fotograf.jpeg
# <br>
# <br>
# Lutfen dosya ismi giriniz: ışık.png
# <br>
# Dosya ismi: isik.png
# </p>

# %%
# 6.Problemin Çözümünü Buraya Yazınız
turkceKarakter = {
    "ı" : "i",
    "ü" : "u",
    "ö" : "o",
    "ç" : "c",
    "ğ" : "g",
    "ş" : "s",
    "İ" : "I",
    "Ü" : "U",
    "Ö" : "O",
    "Ç" : "C",
    "Ğ" : "G",
    "Ş" : "S",
}

dosyaIsim = input("Dosya ismini giriniz.")
turkcesizIsim = str()

for harf in dosyaIsim:
    if harf in turkceKarakter.keys():
        degistir = turkceKarakter.get(harf)
    else:
        degistir = harf
    turkcesizIsim += degistir

print(turkcesizIsim)
# Out:
# isik.png

# %% [markdown]
# # Problem 7 Sayı Tahmin Oyunu ama Bilgisayar Tahmin Ediyor :)
# Sayı tahmin oyunu: İki oyuncudan birinin, 0 ile 100 arasında bir sayı tutması ile başlar. Diğer oyuncu ise tahminler yaparak tutulan sayıyı bulmaya çalışır ve yaptığı her tahminde sayıyı tutmuş olan oyuncudan YUKARI veya AŞAĞI olarak geri bildirim alır. Sayıyı bildiğinde ise rakip oyuncu kaç tahminde (kaç denemede) bildiğini söyler.
#
# Senden yazmanı beklediğimiz program ise Python'ın tahminleri yapan tarafta olacağı bir oyun oluşturman. Yani sen 0 ile 100 arasında bir sayı tutacaksın ardından program senin tuttuğunuz sayıyı bulmaya çalışacak.
# <h4>Sample Input:</h4>
# Bu örnekte aklınızdan 90 tuttuğunuzu varsayalım.
# <p>
# Oyun başlıyor lutfen aklindan bir sayi tut! Tuttun mu, hazır mısın? : 1
# <br>
# Tahmin: 50
# <br>
# Durum: Yukari
# <br>
# Tahmin: 75
# <br>
# Durum: Yukari
# <br>
# Tahmin: 87
# <br>
# Durum: Yukari
# <br>
# Tahmin: 93
# <br>
# Durum: Asagi
# <br>
# Tahmin: 90
# <br>
# Durum: Bildin
# </p>

# %%
# 7.Problemin Çözümünü Buraya Yazınız
import time
counter = 0
tahmin = 50
maks = 100
min = 0
print("Selam ben Tahminci tuttuğun sayıları tahmin edip bulmaya çalışırım hadi bir sayı tut bunun için sana biraz süre vereceğim.")
print("Lütfen sayını 1 ile 100 arasında tut.")
time.sleep(5)
print("Tuttun mu hadi başlayalım.")
print("Şimdi ben ilk tahminimi söyleyeceğim ve sen tahminim küçükse yukarı büyükse aşağı diyeceksin.")
print("Tahmin: 50")
while True:
    durum = input("Yukari - Asagi - Bildin")
    if durum == "Bildin":
        break
    else:
        counter += 1
        if durum == "Yukari":
            min = tahmin
            tahmin = (maks + min)//2 
            print(f"Tahmin: {tahmin}")
        elif durum == "Asagi":
            maks = tahmin
            tahmin = (maks + min)//2
            print(f"Tahmin: {tahmin}")

print("Oh beee sonunda bildim.")
print(f"Vay be bilmem {counter} kadar tahmin almış.")
# Out:
# Selam ben Tahminci tuttuğun sayıları tahmin edip bulmaya çalışırım hadi bir sayı tut bunun için sana biraz süre vereceğim.
# Lütfen sayını 1 ile 100 arasında tut.
# Tuttun mu hadi başlayalım.
# Şimdi ben ilk tahminimi söyleyeceğim ve sen tahminim küçükse yukarı büyükse aşağı diyeceksin.
# Tahmin: 50
# Tahmin: 75
# Tahmin: 62
# Tahmin: 68
# Tahmin: 71
# Tahmin: 69
# Tahmin: 70
# Oh beee sonunda bildim.
# Vay be bilmem 6 kadar tahmin almış

# %% [markdown]
# # Problem 8 Net Yaş Hesaplayıcı
#
# Kullanıcının bugünün güncel tarihine kadar yaşadığı ay, gün, yıl süresini hesaplayan bir Python kodu yazınız. (Her ay 30 gün kabul edilmeyecektir. Kodu yazarken hangi ayın kaç gün olduğuna [Şubat ayının 29 gün olduğu yıllar dahil] dikkat edin.)

# %%
# 8.Problemin Çözümünü Buraya Yazınız
import datetime
a = datetime.datetime.now()
yil = int(input("Doğum yılınızı giriniz."))
ay = int(input("Doğum ayınızı giriniz."))
gün = int(input("Doğum gününüzü giriniz."))
b = datetime.datetime(yil,ay,gün)
c = a-b
c = c.days
print(c)
# Out:
# 6162

# %% [markdown]
# # Problem 9 Tek-Çift
#
# Kullanıcıdan 'q' tuşuna basana kadar rastgele sayılar alın. Tek olanları bir listeye, çift olanları bir başka listeye büyükten küçüğe sıralanacak şekilde atın. Listeleri ekrana yazdıran bir kod yazın.

# %%
# 9.Problemin Çözümünü Buraya Yazınız
tekler = []
ciftler = []
sayilar = []
while True:
    a = input("Lütfen bir sayı giriniz çıkmak için q tuşuna tıklayınız.")
    if a == "q":
        break
    else:
        a = int(a)
        sayilar.append(a)
for sayi in sayilar:
    if sayi % 2 == 0:
        ciftler.append(sayi)
    else:
        tekler.append(sayi)

print(tekler)
print(ciftler)
# Out:
# [5, 7, 9]
# [6, 8]

# %% [markdown]
#  # Problem 10 Altıgen Çizimi
#
# Kullanıcıdan altıgenin kaç satırdan oluşacağı ve orta satırında kaç karakter olacağı bilgisini alarak '*' karakteri ile bir altıgen çizin. (For loop kullanabilirsiniz.)

# %%
# 10.Problemin Çözümünü Buraya Yazınız
def boslukBirak(boslukTane):
    for i in range(boslukTane):
        print(" ", end="")
def yildizKoy(yildizTane):
    for i in range(yildizTane):
        print("*", end="")
satir = int(input("Altıgenin kaç satırdan oluşacağını giriniz. Satır sayısını tek girerseniz düzgün bir şekil çıkar."))
ortaSatir = int(input("Orta satıda kaç tane yıldız olacağını giriniz. Yıldız sayısını tek girerseniz düzgün bir şekil çıkar."))
ortadakiSatir = satir // 2 + 1
for satirNum in range(1, satir+1):
    if satirNum == ortadakiSatir:
        yildizKoy(ortaSatir)
        print("")
    elif satirNum < ortadakiSatir:
        bosluk = (ortadakiSatir - satirNum)*2
        yildiz = ortaSatir - bosluk
        boslukBirak(bosluk//2)
        yildizKoy(yildiz)
        boslukBirak(bosluk//2)
        print("")
    elif satirNum > ortadakiSatir:
        bosluk = (satirNum - ortadakiSatir)*2
        yildiz = ortaSatir - bosluk
        boslukBirak(bosluk//2)
        yildizKoy(yildiz)
        boslukBirak(bosluk//2)
        print("")
# Out:
#           *****************************************
#          *******************************************
#         *********************************************
#        ***********************************************
#       *************************************************
#      ***************************************************
#     *****************************************************
#    *******************************************************
#   *********************************************************
#  ***********************************************************
# *************************************************************
#  ***********************************************************
#   *********************************************************
#    *******************************************************
#     *****************************************************
#      ***************************************************
#       *************************************************
#        ***********************************************
#         *********************************************
#          *******************************************
#           *****************************************
